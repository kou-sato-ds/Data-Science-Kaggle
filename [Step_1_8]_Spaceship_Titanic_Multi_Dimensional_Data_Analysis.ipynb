# %%
# [Step 1-8] Spaceship Titanic: Multi-Dimensional Data Analysis
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score

# 3. データ前処理 (Preprocessing)
# Cabin列をデッキ、番号、サイドに分割（高度な文字列処理）
train[['Deck', 'Num', 'Side']] = train['Cabin'].str.split('/', expand=True)

# 4. 特徴量エンジニアリング (Feature Engineering)
# 各施設での支出額を合計し、個人の「経済力」を一つの指標にする
spending_cols = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
train['TotalSpent'] = train[spending_cols].sum(axis=1)

# 5. モデル選択: 欠損値に強い LightGBM を採用
model = LGBMClassifier(random_state=42)

# 6. モデル評価: 輸送の有無（Transported）の正解率を評価
# print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
