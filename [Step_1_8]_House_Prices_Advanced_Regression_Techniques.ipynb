# %%
# [Step 1-8] House Prices: Advanced Regression Techniques
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# 3. データ前処理 (Preprocessing)
# ターゲット変数（価格）の分布が右に裾を引いているため、対数変換（正規化）を行う
train['SalePrice'] = np.log1p(train['SalePrice'])

# 4. 特徴量エンジニアリング (Feature Engineering)
# 築年数（YearBuilt）とリフォーム年（YearRemodAdd）から住宅の「新しさ」を数値化
train['HouseAge'] = train['YrSold'] - train['YearBuilt']
train['TotalSF'] = train['TotalBsmtSF'] + train['1stFlrSF'] + train['2ndFlrSF'] # 合計面積

# 5. モデル選択: 回帰に強い GradientBoostingRegressor
model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)

# 6. モデル評価: RMSE（平均平方二乗誤差）を算出
# rmse = np.sqrt(mean_squared_error(y_test, y_pred))
